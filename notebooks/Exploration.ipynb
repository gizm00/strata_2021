# %% [markdown]
# ![title](images/lostlake_gorgeflyshop.jpg)
# Lost Lake, Mt Hood National Forest. Image credit: Gorge Fly Shop
#
# ### Lets start with some requirements before we code
# * Want to know where we can go camping, lets start with near Mount Hood
# * Tabular structure will enable fast querying, start out with a dataframe
#
# What campground features do we want to capture?

# %%
from csv import DictReader
import geopandas as gpd
import json
import numpy as np
import pandas as pd
import itertools

from camping.mocks.request import RequestsMock
from camping.util.scraper import Scraper
from camping.util.distance import distance_merge

def max_col_width(w=100):
    pd.set_option('display.max_colwidth', w)

ridb_facilities_url = "https://ridb.recreation.gov/api/v1/facilities"

# %% [markdown]
# #### RIDB - Recreation Information Database - Recreation.gov
#
# [RIDB](https://ridb.recreation.gov/) is a data service spanning multiple US government agencies surfacing data related to recreational opportunities across the country.
#
# ##### Facilities endpoint: `https://ridb.recreation.gov/api/v1/facilities`
# Get a list of facilities by activity. Camping is `activity_id=9`
# Query for facilities nearby a specific point via lat, long, and radius
# Query for facilities in a given state by supplying the 2 digit state code
#
# ##### Campsites endpoint: `https://ridb.recreation.gov/api/v1/facilities/{facility_id}/campsites`
# Campsite specific information for a given facility. Returns a list of campsites at the facility
#
# https://ridb.recreation.gov/docs
#
# #### Make sure you are making appropriate use of resources:
# https://ridb.recreation.gov/ridb-access-agreement
#
#
# #### Follow up - using live RIDB data
# RIDB has an API, which you can access with a Recreation.gov account. In this lab we will use a mock of the API, so you don't need an API key.
#
# If you want to work with live data, go to the Profile area under your account and click the Generate New API key account. Place your key in the `apiKey` field of the `headers` dict below and replace `RequestsMock` with `requests` and you should be good to go!

# %% [markdown]
# Lets take a look at RIDB facilities with camping near Mount Hood Oregon

# %%
# NOTE: If using the mock not change params, mock looks for lat/long/radius
params = {"activity_id":9, "latitude":45.4977712, "longitude":-121.8211673, "radius":15}
headers = {"accept": "application/json", "apikey": "key"}
response = RequestsMock.get(ridb_facilities_url, params, headers=headers)
camping_json  = json.loads(response.text)
df_ridb_facilities = pd.DataFrame(camping_json['RECDATA'])
df_ridb_facilities.head()
# Out:
#   FacilityID LegacyFacilityID OrgFacilityID ParentOrgID ParentRecAreaID  \
# 0     234306            75167      AN375167         131            1102
# 1     232834            71617      AN371617         131            1106
# 2     234075            74082      AN374082         126           16835
# 3     233329            72357      AN372357         131            1106
# 4     122940           122940                       131            1102
#
#                     FacilityName  \
# 0  EAGLE CREEK OVERLOOK GRP SITE
# 1         RILEY HORSE CAMPGROUND
# 2       WILDWOOD RECREATION SITE
# 3       TILLY JANE GUARD STATION
# 4               WYETH CAMPGROUND
#
#                                  FacilityDescription FacilityTypeDescription  \
# 0  <h2>Overview</h2>\nEagle Creek Overlook Group ...              Campground
# 1  <h2>Overview</h2>\nRiley Campground is an eque...              Campground
# 2  <h2>Overview</h2>\n<p>Motorized access to <str...              Campground
# 3  <h2>Overview</h2>\nTilly Jane Guard Station is...              Campground
# 4  <h2>Overview</h2>\nWyeth Campground is just of...              Campground
#
#                            FacilityUseFeeDescription  \
# 0
# 1
# 2  <ul>\n<li>A daily vehicle fee is not included ...
# 3  <p>Reservation Fee: $6.00 (non-refundable)</p>...
# 4
#
#                                   FacilityDirections  ... FacilityMapURL  \
# 0  From Portland, OR; Travel east on Interstate 8...  ...
# 1  From Sandy, travel Highway 26 for 18 miles to ...  ...
# 2  Wildwood Recreation Site is located 39 miles e...  ...
# 3  From Hood River, Oregon, travel south on Highw...  ...
# 4  From east or west on Oregon Interstate 84, tak...  ...
#
#   FacilityAdaAccess                                            GEOJSON  \
# 0                 N  {'TYPE': 'Point', 'COORDINATES': [-121.9308333...
# 1                 N  {'TYPE': 'Point', 'COORDINATES': [-121.8594444...
# 2                 N  {'TYPE': 'Point', 'COORDINATES': [-121.9866667...
# 3                 N  {'TYPE': 'Point', 'COORDINATES': [-121.6480556...
# 4                 N  {'TYPE': 'Point', 'COORDINATES': [-121.7722222...
#
#   FacilityLongitude FacilityLatitude  \
# 0       -121.930833        45.641667
# 1       -121.859444        45.381389
# 2       -121.986667        45.356111
# 3       -121.648056        45.398889
# 4       -121.772222        45.690278
#
#                                             Keywords  StayLimit  Reservable  \
# 0  ECOG,Overlook,Eagle Creek Overlook,Overlook Sh...                   True
# 1                              RILE,MT. HOOD NF - FS                   True
# 2  WIWO,Wildwood Recreation Site,Wild Wood Recrea...                   True
# 3              Guard Station,Cloud Cap Guard Station                   True
# 4                                                                      True
#
#   Enabled LastUpdatedDate
# 0    True      2021-04-13
# 1    True      2021-04-13
# 2    True      2021-04-13
# 3    True      2021-04-13
# 4    True      2021-04-13
#
# [5 rows x 23 columns]

# %% [markdown]
# We have an idea of what we can get from the facilities endpoint:
# * Facility Name & Facility ID
# * Lat/Long
# * Ada Accessability
# * Description
#
# Lets get more specific data on campsites at once of these facilities
# Insert lost lake pic

# %%
columns = ["FacilityName", "FacilityID", "FacilityLatitude", "FacilityLongitude", "FacilityAdaAccess", "FacilityDescription"]
df_ridb_facilities = df_ridb_facilities[columns]
df_ridb_facilities.head()
# Out:
#                     FacilityName FacilityID  FacilityLatitude  \
# 0  EAGLE CREEK OVERLOOK GRP SITE     234306         45.641667
# 1         RILEY HORSE CAMPGROUND     232834         45.381389
# 2       WILDWOOD RECREATION SITE     234075         45.356111
# 3       TILLY JANE GUARD STATION     233329         45.398889
# 4               WYETH CAMPGROUND     122940         45.690278
#
#    FacilityLongitude FacilityAdaAccess  \
# 0        -121.930833                 N
# 1        -121.859444                 N
# 2        -121.986667                 N
# 3        -121.648056                 N
# 4        -121.772222                 N
#
#                                  FacilityDescription
# 0  <h2>Overview</h2>\nEagle Creek Overlook Group ...
# 1  <h2>Overview</h2>\nRiley Campground is an eque...
# 2  <h2>Overview</h2>\n<p>Motorized access to <str...
# 3  <h2>Overview</h2>\nTilly Jane Guard Station is...
# 4  <h2>Overview</h2>\nWyeth Campground is just of...

# %%
df_ridb_facilities.query("FacilityName == 'LOST LAKE RESORT AND CAMPGROUND'")['FacilityID']
# Out:
# 7    251434
# Name: FacilityID, dtype: object

# %%
resp = RequestsMock.get(f"{ridb_facilities_url}/251434/campsites", headers=headers)
campsites_json = json.loads(resp.text)
df_campsites = pd.DataFrame(campsites_json['RECDATA'])
df_campsites.head()
# Out:
#   CampsiteID FacilityID CampsiteName            CampsiteType  TypeOfUse  \
# 0      96115     251434         A021          RV NONELECTRIC  Overnight
# 1      96043     251434         C005          RV NONELECTRIC  Overnight
# 2      96075     251434         D001          RV NONELECTRIC  Overnight
# 3      96104     251434         A009          RV NONELECTRIC  Overnight
# 4      96032     251434         H001  EQUESTRIAN NONELECTRIC  Overnight
#
#         Loop  CampsiteAccessible  CampsiteLongitude  CampsiteLatitude  \
# 0     A Loop               False        -121.816561         45.498111
# 1     C Loop                True        -121.813871         45.496703
# 2     D Loop                True        -121.815180         45.494484
# 3     A Loop               False        -121.816130         45.498334
# 4  Horsecamp                True        -121.811069         45.484083
#
#   CreatedDate LastUpdatedDate  \
# 0  2015-04-09      2020-10-15
# 1  2015-04-09      2020-10-15
# 2  2015-04-09      2020-10-15
# 3  2015-04-09      2020-10-15
# 4  2015-04-09      2020-10-15
#
#                                           ATTRIBUTES  \
# 0  [{'AttributeName': 'Driveway Grade', 'Attribut...
# 1  [{'AttributeName': 'Driveway Entry', 'Attribut...
# 2  [{'AttributeName': 'Accessibility', 'Attribute...
# 3  [{'AttributeName': 'Base Number of People', 'A...
# 4  [{'AttributeName': 'Horse Stall/Corral', 'Attr...
#
#                                          ENTITYMEDIA  \
# 0  [{'EntityMediaID': '567f9beb-d16e-4317-b7e1-28...
# 1  [{'EntityMediaID': '9d9d71ba-a3c2-41b8-b11c-b6...
# 2  [{'EntityMediaID': '7c833b0a-b0cd-4093-8c91-95...
# 3  [{'EntityMediaID': 'd4cec022-4663-4245-a823-a0...
# 4  [{'EntityMediaID': '2590bc58-4289-4a98-934a-6f...
#
#                                   PERMITTEDEQUIPMENT
# 0  [{'EquipmentName': 'Trailer', 'MaxLength': 81}...
# 1  [{'EquipmentName': 'Trailer', 'MaxLength': 54}...
# 2  [{'EquipmentName': 'Trailer', 'MaxLength': 36}...
# 3  [{'EquipmentName': 'Trailer', 'MaxLength': 34}...
# 4      [{'EquipmentName': 'Horse', 'MaxLength': 32}]

# %% [markdown]
# Campsite ATTRIBUTES - JSON describing different characteristics of each campsite
# What characteristics are available?

# %%
set(itertools.chain(*df_campsites['ATTRIBUTES'].apply(lambda x: [entry['AttributeName'] for entry in x])))
# Out:
# {'Accessibility',
#  'BBQ',
#  'Base Number of People',
#  'Base Number of Vehicles',
#  'Campfire Allowed',
#  'Capacity/Size Rating',
#  'Checkin Time',
#  'Checkout Time',
#  'Double Driveway',
#  'Driveway Entry',
#  'Driveway Grade',
#  'Driveway Length',
#  'Driveway Surface',
#  'Fire Pit',
#  'Grills/Fire Ring',
#  'Hike In Distance to Site',
#  'Horse Hitching Post',
#  'Horse Stall/Corral',
#  'IS EQUIPMENT MANDATORY',
#  'Location Rating',
#  'Max Num of People',
#  'Max Num of Vehicles',
#  'Max Vehicle Length',
#  'Min Num of People',
#  'Pets Allowed',
#  'Picnic Table',
#  'Placed on Map',
#  'Platform',
#  'Privacy',
#  'Proximity to Water',
#  'Quiet Area',
#  'Shade',
#  'Site Access',
#  'Site Height/Overhead Clearance',
#  'Site Rating',
#  'Tent Pad',
#  'Tent Pad Length',
#  'Tent Pad Width'}

# %% [markdown]
# #### Transforming campsite data
#
# To make it easier to search for campsites by attribute, we will convert the ATTRIBUTES to columns
# Also, limit the columns we retain to only those we need

# %%
def transform_campsites(campsite_json):
    # First, translate the ATTRIBUTES list into a list of dict of {AttributeName: AttributeValue}
    for i in range(len(campsite_json)):
        campsite_json[i]['AttributeDict'] = [{item['AttributeName']: item['AttributeValue']} for item in campsite_json[i]['ATTRIBUTES']]

    # Next, convert the AttriuteDict to columns
    df = pd.DataFrame(campsite_json)[['ATTRIBUTES', 'CampsiteID', 'CampsiteName', 'FacilityID']]
    df['AttributeDict'] = df['ATTRIBUTES'].apply(lambda x: {item['AttributeName']: item['AttributeValue'] for item in x})
    norm = pd.json_normalize(df['AttributeDict'])
    df = df[['CampsiteID','CampsiteName','FacilityID']].join(norm)
    return df.replace({np.nan: ""})

# %%
campground = transform_campsites(campsites_json['RECDATA'])

# %%
campground.query("`Proximity to Water` != '' & `Fire Pit` != ''")
# Out:
#    CampsiteID CampsiteName FacilityID Driveway Grade Max Num of Vehicles  \
# 15      96099         F004     251434         Slight                   1
# 19      96278         F005     251434         Slight                   1
# 23      96224         F006     251434         Slight                   1
# 41      96264         F002     251434         Slight                   1
# 45      96303         F001     251434         Slight                   1
#
#    Fire Pit Privacy Base Number of Vehicles Base Number of People  \
# 15        Y       Y                       0                     0
# 19        Y       Y                       0                     0
# 23        Y       Y                       0                     0
# 41        Y       Y                       0                     0
# 45        Y       Y                       0                     0
#
#    Grills/Fire Ring  ... Hike In Distance to Site Site Access Accessibility  \
# 15                Y  ...                      275     Hike-In             Y
# 19                Y  ...                      300     Hike-In             Y
# 23                Y  ...                      325     Hike-In             Y
# 41                Y  ...                      225     Hike-In             Y
# 45                Y  ...                      200     Hike-In             Y
#
#    Double Driveway Horse Stall/Corral Horse Hitching Post BBQ Platform  \
# 15                                                          Y        Y
# 19                                                          Y        Y
# 23                                                          Y        Y
# 41                                                          Y        Y
# 45                                                          Y        Y
#
#    Proximity to Water Min Num of People
# 15          Lakefront
# 19          Lakefront
# 23          Lakefront
# 41          Lakefront
# 45          Lakefront
#
# [5 rows x 41 columns]

# %%
# Join this with the facility data. We only want to retain facilities that have camping so we will left join on the campground data
# Keep in mind we only got campsite data for lost lake, so we expect only to see that facility in the response
lost_lake = campground.merge(df_ridb_facilities, on='FacilityID', how='left')
lost_lake.head()
# Out:
#   CampsiteID CampsiteName FacilityID Driveway Grade Max Num of Vehicles  \
# 0      96115         A021     251434         Slight                   1
# 1      96043         C005     251434         Slight                   1
# 2      96075         D001     251434         Slight                   1
# 3      96104         A009     251434         Slight                   1
# 4      96032         H001     251434         Slight                   1
#
#   Fire Pit Privacy Base Number of Vehicles Base Number of People  \
# 0        Y       Y                       0                     0
# 1        Y       Y                       0                     0
# 2        Y       Y
# 3        Y                               0                     0
# 4        Y       Y
#
#   Grills/Fire Ring  ... Horse Hitching Post BBQ Platform Proximity to Water  \
# 0                Y  ...
# 1                Y  ...
# 2                Y  ...
# 3                   ...
# 4                Y  ...                   Y   Y
#
#   Min Num of People                     FacilityName FacilityLatitude  \
# 0                    LOST LAKE RESORT AND CAMPGROUND        45.488889
# 1                    LOST LAKE RESORT AND CAMPGROUND        45.488889
# 2                    LOST LAKE RESORT AND CAMPGROUND        45.488889
# 3                    LOST LAKE RESORT AND CAMPGROUND        45.488889
# 4                    LOST LAKE RESORT AND CAMPGROUND        45.488889
#
#   FacilityLongitude FacilityAdaAccess  \
# 0       -121.821944                 N
# 1       -121.821944                 N
# 2       -121.821944                 N
# 3       -121.821944                 N
# 4       -121.821944                 N
#
#                                  FacilityDescription
# 0  <h2>Overview</h2>\n<p>Lost Lake Campground is ...
# 1  <h2>Overview</h2>\n<p>Lost Lake Campground is ...
# 2  <h2>Overview</h2>\n<p>Lost Lake Campground is ...
# 3  <h2>Overview</h2>\n<p>Lost Lake Campground is ...
# 4  <h2>Overview</h2>\n<p>Lost Lake Campground is ...
#
# [5 rows x 46 columns]

# %% [markdown]
# At this point we have:
# * Ability to search for site characteristics
# * Campground location and site name
#
# Nice to have:
# * Drinking water availabilty
# * Restroom access
# * Current status - may be in facility description but not always

# %%
sc = Scraper("http://www.fs.usda.gov/recarea/mthood/recreation/camping-cabins/recarea/?recid=53228&actid=29", "Lost Lake")
sc.scrape()
# Out:
# {'FacilityStatus': 'Closed',
#  'FacilityLatitude': '45.50080',
#  'FacilityLongitude': '-121.81641',
#  'FacilityElevation': '3200',
#  'Conditions': 'CLOSED FOR THE SEASON\n\xa0\n**Lost Lake is currently limiting parking capacity within the campground and resort area to 50%.\xa0 Friday-Monday, a road barricade is staffed 4 miles below the entrance to the resort.\xa0 Once parking capacity has reached 50% vehicles will be turned around at that location.\xa0 This is the result of parking congestion along the roadways accessing the campground and resort.\xa0 The congestion has made it difficult for emergency personnel to access the site.**\xa0\xa0\nFor the 2020 season, site is operating at 50% capacity.\xa0 Capacity will be met early\xa0on\xa0weekends so strongly consider a mid-week visit instead.\xa0\nForest Road 13 is CLOSED at Lake Branch Bridge at mile post 10.8, just northwest of Lost Lake.',
#  'Reservations': 'Reservations can be made by visiting Recreation.gov. \xa0Reservations must be made 4 days ahead of arrival and can be made up to 6 months in advance for the standard sites and 12 months in advance for the group sites.',
#  'Water': 'Drinking Water',
#  'Restroom': 'Vault Toilet (18)',
#  'FacilityName': 'Lost Lake'}

# %%
nf_sites = []
with open('../data/NF_sites/OR_sitelist.csv') as f:
    reader = DictReader(f)
    for row in reader:
        nf_sites.append(row)
nf_sites
# Out:
# [{'site_name': 'East Lemolo Campground',
#   'site_url': 'https://www.fs.usda.gov/recarea/umpqua/recarea/?recid=63492'},
#  {'site_name': 'Magone Lake Campground',
#   'site_url': 'https://www.fs.usda.gov/recarea/malheur/recarea/?recid=39964'},
#  {'site_name': 'East Davis Lake Campground',
#   'site_url': 'https://www.fs.usda.gov/recarea/deschutes/recarea/?recid=38854'},
#  {'site_name': 'Lost Lake Campground Resort and Day Use Area',
#   'site_url': 'https://www.fs.usda.gov/recarea/mthood/recarea/?recid=53228'},
#  {'site_name': 'Anthony Lake',
#   'site_url': 'https://www.fs.usda.gov/recarea/wallowa-whitman/recarea/?recid=52199'},
#  {'site_name': 'Musick Guard Station',
#   'site_url': 'https://www.fs.usda.gov/recarea/umpqua/recarea/?recid=63428'},
#  {'site_name': 'Lost Lake Campground',
#   'site_url': 'https://www.fs.usda.gov/recarea/willamette/recarea/?recid=13362'}]

# %%
nf_data = []
for site in nf_sites:
    sc = Scraper(site['site_url'], site['site_name'])
    nf_data.append(sc.scrape())
nf_df = pd.DataFrame(nf_data)
nf_df
# Out:
#        FacilityStatus   FacilityLatitude  FacilityLongitude FacilityElevation  \
# 0  Temporarily Closed          43.310697        -122.162651        4,150 feet
# 1                Open           44.55266          -118.9094              5500
# 2              Closed            43.5867         -121.85667              4400
# 3              Closed           45.50080         -121.81641              3200
# 4              Closed   44.9625128531073  -118.228574730768              7150
# 5  Temporarily Closed          43.581026        -122.641745        5,000 feet
# 6  Temporarily Closed  44.42927714677809  -121.912474623539         4200 feet
#
#                                           Conditions  \
# 0  10/28/2020: Closed for the season. Will reopen...
# 1  01/22/2021: The campground is is closed and th...
# 2                                                NaN
# 3  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 4                                 Current Conditions
# 5  10/09/2020- This site is currently closed per ...
# 6                                                NaN
#
#                                         Reservations  \
# 0  Reservations can be made at www.recreation.gov...
# 1  To reserve the group site, visit www.recreatio...
# 2  Reservations can be online through Recreation....
# 3  Reservations can be made by visiting Recreatio...
# 4              https://anthonylakes.com/campgrounds/
# 5                                                NaN
# 6  No advance reservations. All sites are first c...
#
#                                    FacilityName           Water  \
# 0                        East Lemolo Campground             NaN
# 1                        Magone Lake Campground  Drinking Water
# 2                    East Davis Lake Campground   Potable Water
# 3  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 4                                  Anthony Lake   Potable Water
# 5                          Musick Guard Station             NaN
# 6                          Lost Lake Campground             NaN
#
#             Restroom       Open Season
# 0                NaN               NaN
# 1      Vault Toilets               NaN
# 2       Vault Toilet               NaN
# 3  Vault Toilet (18)               NaN
# 4      Vault Toilets  July - September
# 5                NaN      Early Summer
# 6                NaN               NaN

# %%
dm = distance_merge(nf_df, lost_lake, 2000, 'ridb', 'nf')
# Out:
# /Users/gizmo/.pyenv/versions/3.8.5/envs/strata_venv/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /Users/gizmo/.pyenv/versions/3.8.5/envs/strata_venv/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
dm
# Out:
#    CampsiteID  CampsiteName FacilityID Driveway Grade Max Num of Vehicles  \
# 0       96115          A021     251434         Slight                   1
# 1       96043          C005     251434         Slight                   1
# 2       96075          D001     251434         Slight                   1
# 3       96104          A009     251434         Slight                   1
# 4       96032          H001     251434         Slight                   1
# 5       96014          B012     251434         Severe                   1
# 6       96127          B010     251434         Slight                   1
# 7       96083          A017     251434       Moderate                   1
# 8       96023          B004     251434       Moderate                   1
# 9       96040          D012     251434         Slight                   1
# 10      96156          C002     251434         Slight                   1
# 11      96103          H003     251434         Slight                   1
# 12      96065          D016     251434         Slight                   1
# 13      96149          D009     251434         Slight                   1
# 14      96003          A022     251434         Slight                   1
# 15      96099          F004     251434         Slight                   1
# 16      96107          A004     251434         Slight                   1
# 17      96086          D018     251434         Slight                   1
# 18      96067          B003     251434       Moderate                   1
# 19      96278          F005     251434         Slight                   1
# 20      96176   A007a and b     251434         Slight                   3
# 21      96033          B006     251434         Slight                   1
# 22      96140          B009     251434         Slight                   1
# 23      96224          F006     251434         Slight                   1
# 24      96101          H005     251434         Slight                   1
# 25      96212  A006 a and b     251434         Slight                   3
# 26      96080          D002     251434         Slight                   1
# 27      96112          D020     251434         Slight                   1
# 28      96072          D005     251434         Slight                   1
# 29      96056          B007     251434         Slight                   1
# 30      96012          A014     251434         Slight                   1
# 31      96097          D010     251434         Slight                   1
# 32      96136          D007     251434         Slight                   1
# 33      96114          D024     251434         Slight                   1
# 34      96098          A011     251434       Moderate                   1
# 35      96028          B013     251434         Slight                   1
# 36      96131          C006     251434         Slight                   1
# 37      96019          C010     251434         Slight                   1
# 38      96141          A012     251434       Moderate                   1
# 39      96004          A019     251434         Slight                   1
# 40      96095          A020     251434         Slight                   1
# 41      96264          F002     251434         Slight                   1
# 42      96057          B014     251434         Slight                   1
# 43      96073          D017     251434         Slight                   1
# 44      96111          C008     251434         Slight                   1
# 45      96303          F001     251434         Slight                   1
# 46      96053          B011     251434         Slight                   1
# 47      96013          B002     251434       Moderate                   1
# 48      96009          D004     251434         Slight                   1
# 49      96085          D015     251434         Slight                   1
#
#    Fire Pit Privacy Base Number of Vehicles Base Number of People  \
# 0         Y       Y                       0                     0
# 1         Y       Y                       0                     0
# 2         Y       Y
# 3         Y                               0                     0
# 4         Y       Y
# 5         Y       Y                       0                     0
# 6         Y       Y                       0                     0
# 7         Y                               0                     0
# 8         Y                               0                     0
# 9         Y
# 10        Y       Y                       0                     0
# 11        Y       Y
# 12        Y
# 13        Y
# 14        Y       Y                       0                     0
# 15        Y       Y                       0                     0
# 16        Y       Y                       0                     0
# 17        Y       Y
# 18        Y       Y                       0                     0
# 19        Y       Y                       0                     0
# 20        Y                               0                     0
# 21        Y                               0                     0
# 22        Y       Y                       0                     0
# 23        Y       Y                       0                     0
# 24        Y       Y
# 25        Y       Y                       0                     0
# 26        Y       Y
# 27        Y       Y
# 28        Y       Y
# 29        Y                               0                     0
# 30        Y       Y                       0                     0
# 31        Y
# 32        Y       Y
# 33        Y       Y
# 34        Y       Y                       0                     0
# 35        Y       Y                       0                     0
# 36        Y       Y                       0                     0
# 37        Y       Y                       0                     0
# 38        Y                               0                     0
# 39        Y       Y                       0                     0
# 40        Y       Y                       0                     0
# 41        Y       Y                       0                     0
# 42        Y       Y                       0                     0
# 43        Y
# 44        Y       Y                       0                     0
# 45        Y       Y                       0                     0
# 46        Y       Y                       0                     0
# 47        Y       Y                       0                     0
# 48        Y
# 49        Y       Y
#
#    Grills/Fire Ring  ... FacilityStatus FacilityLatitude_nf  \
# 0                 Y  ...         Closed            45.50080
# 1                 Y  ...         Closed            45.50080
# 2                 Y  ...         Closed            45.50080
# 3                    ...         Closed            45.50080
# 4                 Y  ...         Closed            45.50080
# 5                    ...         Closed            45.50080
# 6                    ...         Closed            45.50080
# 7                 Y  ...         Closed            45.50080
# 8                 Y  ...         Closed            45.50080
# 9                 Y  ...         Closed            45.50080
# 10                Y  ...         Closed            45.50080
# 11                Y  ...         Closed            45.50080
# 12                Y  ...         Closed            45.50080
# 13                   ...         Closed            45.50080
# 14                Y  ...         Closed            45.50080
# 15                Y  ...         Closed            45.50080
# 16                   ...         Closed            45.50080
# 17                Y  ...         Closed            45.50080
# 18                Y  ...         Closed            45.50080
# 19                Y  ...         Closed            45.50080
# 20                Y  ...         Closed            45.50080
# 21                Y  ...         Closed            45.50080
# 22                Y  ...         Closed            45.50080
# 23                Y  ...         Closed            45.50080
# 24                   ...         Closed            45.50080
# 25                Y  ...         Closed            45.50080
# 26                Y  ...         Closed            45.50080
# 27                Y  ...         Closed            45.50080
# 28                Y  ...         Closed            45.50080
# 29                Y  ...         Closed            45.50080
# 30                Y  ...         Closed            45.50080
# 31                Y  ...         Closed            45.50080
# 32                Y  ...         Closed            45.50080
# 33                Y  ...         Closed            45.50080
# 34                   ...         Closed            45.50080
# 35                Y  ...         Closed            45.50080
# 36                Y  ...         Closed            45.50080
# 37                   ...         Closed            45.50080
# 38                Y  ...         Closed            45.50080
# 39                   ...         Closed            45.50080
# 40                Y  ...         Closed            45.50080
# 41                Y  ...         Closed            45.50080
# 42                Y  ...         Closed            45.50080
# 43                Y  ...         Closed            45.50080
# 44                Y  ...         Closed            45.50080
# 45                Y  ...         Closed            45.50080
# 46                   ...         Closed            45.50080
# 47                Y  ...         Closed            45.50080
# 48                Y  ...         Closed            45.50080
# 49                Y  ...         Closed            45.50080
#
#    FacilityLongitude_nf FacilityElevation  \
# 0            -121.81641              3200
# 1            -121.81641              3200
# 2            -121.81641              3200
# 3            -121.81641              3200
# 4            -121.81641              3200
# 5            -121.81641              3200
# 6            -121.81641              3200
# 7            -121.81641              3200
# 8            -121.81641              3200
# 9            -121.81641              3200
# 10           -121.81641              3200
# 11           -121.81641              3200
# 12           -121.81641              3200
# 13           -121.81641              3200
# 14           -121.81641              3200
# 15           -121.81641              3200
# 16           -121.81641              3200
# 17           -121.81641              3200
# 18           -121.81641              3200
# 19           -121.81641              3200
# 20           -121.81641              3200
# 21           -121.81641              3200
# 22           -121.81641              3200
# 23           -121.81641              3200
# 24           -121.81641              3200
# 25           -121.81641              3200
# 26           -121.81641              3200
# 27           -121.81641              3200
# 28           -121.81641              3200
# 29           -121.81641              3200
# 30           -121.81641              3200
# 31           -121.81641              3200
# 32           -121.81641              3200
# 33           -121.81641              3200
# 34           -121.81641              3200
# 35           -121.81641              3200
# 36           -121.81641              3200
# 37           -121.81641              3200
# 38           -121.81641              3200
# 39           -121.81641              3200
# 40           -121.81641              3200
# 41           -121.81641              3200
# 42           -121.81641              3200
# 43           -121.81641              3200
# 44           -121.81641              3200
# 45           -121.81641              3200
# 46           -121.81641              3200
# 47           -121.81641              3200
# 48           -121.81641              3200
# 49           -121.81641              3200
#
#                                            Conditions  \
# 0   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 1   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 2   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 3   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 4   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 5   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 6   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 7   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 8   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 9   CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 10  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 11  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 12  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 13  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 14  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 15  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 16  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 17  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 18  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 19  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 20  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 21  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 22  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 23  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 24  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 25  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 26  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 27  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 28  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 29  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 30  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 31  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 32  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 33  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 34  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 35  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 36  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 37  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 38  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 39  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 40  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 41  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 42  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 43  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 44  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 45  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 46  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 47  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 48  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
# 49  CLOSED FOR THE SEASON\n \n**Lost Lake is curre...
#
#                                          Reservations  \
# 0   Reservations can be made by visiting Recreatio...
# 1   Reservations can be made by visiting Recreatio...
# 2   Reservations can be made by visiting Recreatio...
# 3   Reservations can be made by visiting Recreatio...
# 4   Reservations can be made by visiting Recreatio...
# 5   Reservations can be made by visiting Recreatio...
# 6   Reservations can be made by visiting Recreatio...
# 7   Reservations can be made by visiting Recreatio...
# 8   Reservations can be made by visiting Recreatio...
# 9   Reservations can be made by visiting Recreatio...
# 10  Reservations can be made by visiting Recreatio...
# 11  Reservations can be made by visiting Recreatio...
# 12  Reservations can be made by visiting Recreatio...
# 13  Reservations can be made by visiting Recreatio...
# 14  Reservations can be made by visiting Recreatio...
# 15  Reservations can be made by visiting Recreatio...
# 16  Reservations can be made by visiting Recreatio...
# 17  Reservations can be made by visiting Recreatio...
# 18  Reservations can be made by visiting Recreatio...
# 19  Reservations can be made by visiting Recreatio...
# 20  Reservations can be made by visiting Recreatio...
# 21  Reservations can be made by visiting Recreatio...
# 22  Reservations can be made by visiting Recreatio...
# 23  Reservations can be made by visiting Recreatio...
# 24  Reservations can be made by visiting Recreatio...
# 25  Reservations can be made by visiting Recreatio...
# 26  Reservations can be made by visiting Recreatio...
# 27  Reservations can be made by visiting Recreatio...
# 28  Reservations can be made by visiting Recreatio...
# 29  Reservations can be made by visiting Recreatio...
# 30  Reservations can be made by visiting Recreatio...
# 31  Reservations can be made by visiting Recreatio...
# 32  Reservations can be made by visiting Recreatio...
# 33  Reservations can be made by visiting Recreatio...
# 34  Reservations can be made by visiting Recreatio...
# 35  Reservations can be made by visiting Recreatio...
# 36  Reservations can be made by visiting Recreatio...
# 37  Reservations can be made by visiting Recreatio...
# 38  Reservations can be made by visiting Recreatio...
# 39  Reservations can be made by visiting Recreatio...
# 40  Reservations can be made by visiting Recreatio...
# 41  Reservations can be made by visiting Recreatio...
# 42  Reservations can be made by visiting Recreatio...
# 43  Reservations can be made by visiting Recreatio...
# 44  Reservations can be made by visiting Recreatio...
# 45  Reservations can be made by visiting Recreatio...
# 46  Reservations can be made by visiting Recreatio...
# 47  Reservations can be made by visiting Recreatio...
# 48  Reservations can be made by visiting Recreatio...
# 49  Reservations can be made by visiting Recreatio...
#
#                                  FacilityName_nf           Water  \
# 0   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 1   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 2   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 3   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 4   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 5   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 6   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 7   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 8   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 9   Lost Lake Campground Resort and Day Use Area  Drinking Water
# 10  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 11  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 12  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 13  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 14  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 15  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 16  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 17  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 18  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 19  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 20  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 21  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 22  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 23  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 24  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 25  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 26  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 27  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 28  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 29  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 30  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 31  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 32  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 33  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 34  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 35  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 36  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 37  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 38  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 39  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 40  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 41  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 42  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 43  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 44  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 45  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 46  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 47  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 48  Lost Lake Campground Resort and Day Use Area  Drinking Water
# 49  Lost Lake Campground Resort and Day Use Area  Drinking Water
#
#              Restroom Open Season
# 0   Vault Toilet (18)         NaN
# 1   Vault Toilet (18)         NaN
# 2   Vault Toilet (18)         NaN
# 3   Vault Toilet (18)         NaN
# 4   Vault Toilet (18)         NaN
# 5   Vault Toilet (18)         NaN
# 6   Vault Toilet (18)         NaN
# 7   Vault Toilet (18)         NaN
# 8   Vault Toilet (18)         NaN
# 9   Vault Toilet (18)         NaN
# 10  Vault Toilet (18)         NaN
# 11  Vault Toilet (18)         NaN
# 12  Vault Toilet (18)         NaN
# 13  Vault Toilet (18)         NaN
# 14  Vault Toilet (18)         NaN
# 15  Vault Toilet (18)         NaN
# 16  Vault Toilet (18)         NaN
# 17  Vault Toilet (18)         NaN
# 18  Vault Toilet (18)         NaN
# 19  Vault Toilet (18)         NaN
# 20  Vault Toilet (18)         NaN
# 21  Vault Toilet (18)         NaN
# 22  Vault Toilet (18)         NaN
# 23  Vault Toilet (18)         NaN
# 24  Vault Toilet (18)         NaN
# 25  Vault Toilet (18)         NaN
# 26  Vault Toilet (18)         NaN
# 27  Vault Toilet (18)         NaN
# 28  Vault Toilet (18)         NaN
# 29  Vault Toilet (18)         NaN
# 30  Vault Toilet (18)         NaN
# 31  Vault Toilet (18)         NaN
# 32  Vault Toilet (18)         NaN
# 33  Vault Toilet (18)         NaN
# 34  Vault Toilet (18)         NaN
# 35  Vault Toilet (18)         NaN
# 36  Vault Toilet (18)         NaN
# 37  Vault Toilet (18)         NaN
# 38  Vault Toilet (18)         NaN
# 39  Vault Toilet (18)         NaN
# 40  Vault Toilet (18)         NaN
# 41  Vault Toilet (18)         NaN
# 42  Vault Toilet (18)         NaN
# 43  Vault Toilet (18)         NaN
# 44  Vault Toilet (18)         NaN
# 45  Vault Toilet (18)         NaN
# 46  Vault Toilet (18)         NaN
# 47  Vault Toilet (18)         NaN
# 48  Vault Toilet (18)         NaN
# 49  Vault Toilet (18)         NaN
#
# [50 rows x 58 columns]

# %%
# putting it all together
ridb_facilities_url = "https://ridb.recreation.gov/api/v1/facilities"
params = {"activity_id":9, "state":"OR"}
headers = {"accept": "application/json", "apikey": "key"}
campground_info = pd.DataFrame()

# Get RIDB Facilities with camping
response = RequestsMock.get(ridb_facilities_url, params, headers=headers)
camping_json  = json.loads(response.text)
df_ridb_camping = pd.DataFrame(camping_json['RECDATA'])

for facility in camping_json['RECDATA']:
    campground_url = f"{ridb_facilities_url}/{facility['FacilityID']}/campsites"
    resp = RequestsMock.get(campground_url, headers=headers)
    campsites = json.loads(resp.text)
    if len(campsites['RECDATA']) > 0:
        df_campsites = transform_campsites(campsites['RECDATA'])
        campground_info = campground_info.append(df_campsites.merge(df_ridb_camping, on='FacilityID', how='left'))

campground_info = campground_info.replace(np.nan, '')
nf_data = []
with open('../data/NF_sites/OR_sitelist.csv') as f:
    reader = DictReader(f)
    for row in reader:
        sc = Scraper(row['site_url'], row['site_name'])
        nf_data.append(sc.scrape())
nf_df = pd.DataFrame(nf_data)
merged = distance_merge(nf_df, campground_info, 2000, 'ridb', 'nf')
# Out:
# /Users/gizmo/.pyenv/versions/3.8.5/envs/strata_venv/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /Users/gizmo/.pyenv/versions/3.8.5/envs/strata_venv/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
merged.query("`Proximity to Water` != '' & `Pets Allowed` != ''")[['FacilityName_ridb', 'Proximity to Water', 'Pets Allowed', 'FacilityStatus']]
# Out:
#                   FacilityName_ridb Proximity to Water Pets Allowed  \
# 8                      Anthony Lake          Lakefront          Yes
# 12                     Anthony Lake                N/A          Yes
# 0        NORTH FORK CAMPGROUND (OR)         Riverfront          Yes
# 2        NORTH FORK CAMPGROUND (OR)         Riverfront          Yes
# 7        NORTH FORK CAMPGROUND (OR)         Riverfront          Yes
# 15  LOST LAKE RESORT AND CAMPGROUND          Lakefront          Yes
# 19  LOST LAKE RESORT AND CAMPGROUND          Lakefront          Yes
# 23  LOST LAKE RESORT AND CAMPGROUND          Lakefront          Yes
# 41  LOST LAKE RESORT AND CAMPGROUND          Lakefront          Yes
# 45  LOST LAKE RESORT AND CAMPGROUND          Lakefront          Yes
#
#    FacilityStatus
# 8          Closed
# 12         Closed
# 0             NaN
# 2             NaN
# 7             NaN
# 15         Closed
# 19         Closed
# 23         Closed
# 41         Closed
# 45         Closed
